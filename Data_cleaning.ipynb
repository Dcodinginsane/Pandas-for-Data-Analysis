# %% [markdown]
# <a href="https://colab.research.google.com/github/Dcodinginsane/Pandas-for-Data-Analysis/blob/main/Data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data = https://docs.google.com/spreadsheets/d/1Lqb6sGkmbq6UzBbNoOdmhQkbefr4_xZ1/edit#gid=361340845

# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_excel(pwd + "/Data - Survey Monkey Output Edited.xlsx", sheet_name="Edited_Data")
dataset
# Out:
#      Respondent ID          Start Date            End Date  Email Address  \
# 0       5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1       2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2       4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3       5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4       3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ..             ...                 ...                 ...            ...
# 193     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 194     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 195     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 196     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 197     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# 0           NaN        NaN            NaN
# 1           NaN        NaN            NaN
# 2           NaN        NaN            NaN
# 3           NaN        NaN            NaN
# 4           NaN        NaN            NaN
# ..          ...        ...            ...
# 193         NaN        NaN            NaN
# 194         NaN        NaN            NaN
# 195         NaN        NaN            NaN
# 196         NaN        NaN            NaN
# 197         NaN        NaN            NaN
#
#     Identify which division you work in. - Response  \
# 0                                    Infrastructure
# 1                                           Finance
# 2                                    Infrastructure
# 3                                    Infrastructure
# 4                                   Port Operations
# ..                                              ...
# 193                                  Infrastructure
# 194                                         Finance
# 195                                 Port Operations
# 196                                  Infrastructure
# 197                          Information Technology
#
#     Identify which division you work in. - Other (please specify)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
#
#     Which of the following best describes your position level? - Response  \
# 0                                                Staff
# 1                                                Staff
# 2                                      Department Lead
# 3                                              Manager
# 4                                              Manager
# ..                                                 ...
# 193                                    Department Lead
# 194                                              Staff
# 195                                              Staff
# 196                                            Manager
# 197                                              Staff
#
#      ... Question 29 - Response 8 Question 29 - Response 9  \
# 0    ...                      NaN                 Answer 8
# 1    ...                      NaN                 Answer 5
# 2    ...                      NaN                      NaN
# 3    ...                 Answer 2                 Answer 5
# 4    ...                      NaN                 Answer 5
# ..   ...                      ...                      ...
# 193  ...                 Answer 1                 Answer 1
# 194  ...                 Answer 5                      NaN
# 195  ...                      NaN                 Answer 7
# 196  ...                 Answer 2                      NaN
# 197  ...                 Answer 3                      NaN
#
#     Question 29 - Response 10 Question 29 - Response 11  \
# 0                    Answer 8                  Answer 4
# 1                         NaN                       NaN
# 2                    Answer 4                  Answer 4
# 3                    Answer 7                       NaN
# 4                    Answer 4                  Answer 4
# ..                        ...                       ...
# 193                  Answer 3                  Answer 6
# 194                  Answer 5                       NaN
# 195                       NaN                       NaN
# 196                  Answer 3                  Answer 5
# 197                  Answer 7                       NaN
#
#     Question 29 - Response 12 Question 29 - Response 13  \
# 0                         NaN                       NaN
# 1                    Answer 2                       NaN
# 2                    Answer 6                       NaN
# 3                    Answer 6                       NaN
# 4                    Answer 7                  Answer 7
# ..                        ...                       ...
# 193                  Answer 6                  Answer 8
# 194                       NaN                  Answer 2
# 195                       NaN                       NaN
# 196                       NaN                  Answer 8
# 197                       NaN                       NaN
#
#     Question 29 - Response 14 Question 30 - Response 1  \
# 0                    Answer 5                      NaN
# 1                    Answer 5                      NaN
# 2                    Answer 6                      NaN
# 3                    Answer 7                 Answer 7
# 4                         NaN                 Answer 7
# ..                        ...                      ...
# 193                       NaN                      NaN
# 194                       NaN                      NaN
# 195                       NaN                      NaN
# 196                  Answer 3                 Answer 3
# 197                       NaN                 Answer 3
#
#     Question 30 - Response 2 Question 30 - Response 3
# 0                        NaN                      NaN
# 1                        NaN                 Answer 1
# 2                   Answer 1                      NaN
# 3                   Answer 1                 Answer 6
# 4                        NaN                 Answer 8
# ..                       ...                      ...
# 193                      NaN                 Answer 8
# 194                      NaN                 Answer 6
# 195                 Answer 3                      NaN
# 196                      NaN                      NaN
# 197                      NaN                      NaN
#
# [198 rows x 100 columns]

# %%
dataset_modified = dataset.copy()
dataset_modified
# Out:
#      Respondent ID          Start Date            End Date  Email Address  \
# 0       5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1       2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2       4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3       5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4       3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ..             ...                 ...                 ...            ...
# 193     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 194     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 195     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 196     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 197     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# 0           NaN        NaN            NaN
# 1           NaN        NaN            NaN
# 2           NaN        NaN            NaN
# 3           NaN        NaN            NaN
# 4           NaN        NaN            NaN
# ..          ...        ...            ...
# 193         NaN        NaN            NaN
# 194         NaN        NaN            NaN
# 195         NaN        NaN            NaN
# 196         NaN        NaN            NaN
# 197         NaN        NaN            NaN
#
#     Identify which division you work in. - Response  \
# 0                                    Infrastructure
# 1                                           Finance
# 2                                    Infrastructure
# 3                                    Infrastructure
# 4                                   Port Operations
# ..                                              ...
# 193                                  Infrastructure
# 194                                         Finance
# 195                                 Port Operations
# 196                                  Infrastructure
# 197                          Information Technology
#
#     Identify which division you work in. - Other (please specify)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
#
#     Which of the following best describes your position level? - Response  \
# 0                                                Staff
# 1                                                Staff
# 2                                      Department Lead
# 3                                              Manager
# 4                                              Manager
# ..                                                 ...
# 193                                    Department Lead
# 194                                              Staff
# 195                                              Staff
# 196                                            Manager
# 197                                              Staff
#
#      ... Question 29 - Response 8 Question 29 - Response 9  \
# 0    ...                      NaN                 Answer 8
# 1    ...                      NaN                 Answer 5
# 2    ...                      NaN                      NaN
# 3    ...                 Answer 2                 Answer 5
# 4    ...                      NaN                 Answer 5
# ..   ...                      ...                      ...
# 193  ...                 Answer 1                 Answer 1
# 194  ...                 Answer 5                      NaN
# 195  ...                      NaN                 Answer 7
# 196  ...                 Answer 2                      NaN
# 197  ...                 Answer 3                      NaN
#
#     Question 29 - Response 10 Question 29 - Response 11  \
# 0                    Answer 8                  Answer 4
# 1                         NaN                       NaN
# 2                    Answer 4                  Answer 4
# 3                    Answer 7                       NaN
# 4                    Answer 4                  Answer 4
# ..                        ...                       ...
# 193                  Answer 3                  Answer 6
# 194                  Answer 5                       NaN
# 195                       NaN                       NaN
# 196                  Answer 3                  Answer 5
# 197                  Answer 7                       NaN
#
#     Question 29 - Response 12 Question 29 - Response 13  \
# 0                         NaN                       NaN
# 1                    Answer 2                       NaN
# 2                    Answer 6                       NaN
# 3                    Answer 6                       NaN
# 4                    Answer 7                  Answer 7
# ..                        ...                       ...
# 193                  Answer 6                  Answer 8
# 194                       NaN                  Answer 2
# 195                       NaN                       NaN
# 196                       NaN                  Answer 8
# 197                       NaN                       NaN
#
#     Question 29 - Response 14 Question 30 - Response 1  \
# 0                    Answer 5                      NaN
# 1                    Answer 5                      NaN
# 2                    Answer 6                      NaN
# 3                    Answer 7                 Answer 7
# 4                         NaN                 Answer 7
# ..                        ...                      ...
# 193                       NaN                      NaN
# 194                       NaN                      NaN
# 195                       NaN                      NaN
# 196                  Answer 3                 Answer 3
# 197                       NaN                 Answer 3
#
#     Question 30 - Response 2 Question 30 - Response 3
# 0                        NaN                      NaN
# 1                        NaN                 Answer 1
# 2                   Answer 1                      NaN
# 3                   Answer 1                 Answer 6
# 4                        NaN                 Answer 8
# ..                       ...                      ...
# 193                      NaN                 Answer 8
# 194                      NaN                 Answer 6
# 195                 Answer 3                      NaN
# 196                      NaN                      NaN
# 197                      NaN                      NaN
#
# [198 rows x 100 columns]

# %%
columns_to_drop = ['Start Date', 'End Date', 'Email Address', 'First Name', 'Last Name', 'Custom Data 1']
columns_to_drop
# Out:
# ['Start Date',
#  'End Date',
#  'Email Address',
#  'First Name',
#  'Last Name',
#  'Custom Data 1']

# %%
id_vars = list(dataset_modified.columns)[ : 8]
value_vars = list(dataset_modified.columns)[8 : ]
# value_vars

# %%
dataset_melted = dataset_modified.melt(id_vars=id_vars, value_vars = value_vars, var_name="Question + Subquestion", value_name="Answer")
dataset_melted
# Out:
#        Respondent ID          Start Date            End Date  Email Address  \
# 0         5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1         2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2         4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3         5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4         3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ...              ...                 ...                 ...            ...
# 18211     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 18212     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 18213     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 18214     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 18215     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#        First Name  Last Name  Custom Data 1  \
# 0             NaN        NaN            NaN
# 1             NaN        NaN            NaN
# 2             NaN        NaN            NaN
# 3             NaN        NaN            NaN
# 4             NaN        NaN            NaN
# ...           ...        ...            ...
# 18211         NaN        NaN            NaN
# 18212         NaN        NaN            NaN
# 18213         NaN        NaN            NaN
# 18214         NaN        NaN            NaN
# 18215         NaN        NaN            NaN
#
#       Identify which division you work in. - Response  \
# 0                                      Infrastructure
# 1                                             Finance
# 2                                      Infrastructure
# 3                                      Infrastructure
# 4                                     Port Operations
# ...                                               ...
# 18211                                  Infrastructure
# 18212                                         Finance
# 18213                                 Port Operations
# 18214                                  Infrastructure
# 18215                          Information Technology
#
#                                   Question + Subquestion    Answer
# 0      Identify which division you work in. - Other (...       NaN
# 1      Identify which division you work in. - Other (...       NaN
# 2      Identify which division you work in. - Other (...       NaN
# 3      Identify which division you work in. - Other (...       NaN
# 4      Identify which division you work in. - Other (...       NaN
# ...                                                  ...       ...
# 18211                           Question 30 - Response 3  Answer 8
# 18212                           Question 30 - Response 3  Answer 6
# 18213                           Question 30 - Response 3       NaN
# 18214                           Question 30 - Response 3       NaN
# 18215                           Question 30 - Response 3       NaN
#
# [18216 rows x 10 columns]

# %%
questions_import = pd.read_excel(pwd + "/Data - Survey Monkey Output Edited.xlsx", sheet_name="Question")
questions_import
# Out:
#      Raw Question Raw Subquestion       Question  Subquestion  \
# 0   Respondent ID             NaN  Respondent ID          NaN
# 1      Start Date             NaN     Start Date          NaN
# 2        End Date             NaN       End Date          NaN
# 3   Email Address             NaN  Email Address          NaN
# 4      First Name             NaN     First Name          NaN
# ..            ...             ...            ...          ...
# 95            NaN     Response 13    Question 29  Response 13
# 96            NaN     Response 14    Question 29  Response 14
# 97    Question 30      Response 1    Question 30   Response 1
# 98            NaN      Response 2    Question 30   Response 2
# 99            NaN      Response 3    Question 30   Response 3
#
#        Question + Subquestion
# 0               Respondent ID
# 1                  Start Date
# 2                    End Date
# 3               Email Address
# 4                  First Name
# ..                        ...
# 95  Question 29 - Response 13
# 96  Question 29 - Response 14
# 97   Question 30 - Response 1
# 98   Question 30 - Response 2
# 99   Question 30 - Response 3
#
# [100 rows x 5 columns]

# %%
questions = questions_import.copy()
questions.drop(columns=["Raw Question", "Raw Subquestion", "Subquestion"], inplace=True)

# %%
questions
# Out:
#          Question     Question + Subquestion
# 0   Respondent ID              Respondent ID
# 1      Start Date                 Start Date
# 2        End Date                   End Date
# 3   Email Address              Email Address
# 4      First Name                 First Name
# ..            ...                        ...
# 95    Question 29  Question 29 - Response 13
# 96    Question 29  Question 29 - Response 14
# 97    Question 30   Question 30 - Response 1
# 98    Question 30   Question 30 - Response 2
# 99    Question 30   Question 30 - Response 3
#
# [100 rows x 2 columns]

# %%
questions.dropna(inplace=True)

# %%
questions
# Out:
#          Question     Question + Subquestion
# 0   Respondent ID              Respondent ID
# 1      Start Date                 Start Date
# 2        End Date                   End Date
# 3   Email Address              Email Address
# 4      First Name                 First Name
# ..            ...                        ...
# 95    Question 29  Question 29 - Response 13
# 96    Question 29  Question 29 - Response 14
# 97    Question 30   Question 30 - Response 1
# 98    Question 30   Question 30 - Response 2
# 99    Question 30   Question 30 - Response 3
#
# [100 rows x 2 columns]

# %%
dataset_merged = pd.merge(left=dataset_melted, right=questions, how="left", left_on="Question + Subquestion", right_on="Question + Subquestion")
print("Original Data", len(dataset_melted))
print("Merged Data", len(dataset_merged))
dataset_merged
# Out:
# Original Data 18216
# Merged Data 18216
#        Respondent ID          Start Date            End Date  Email Address  \
# 0         5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1         2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2         4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3         5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4         3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ...              ...                 ...                 ...            ...
# 18211     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 18212     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 18213     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 18214     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 18215     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#        First Name  Last Name  Custom Data 1  \
# 0             NaN        NaN            NaN
# 1             NaN        NaN            NaN
# 2             NaN        NaN            NaN
# 3             NaN        NaN            NaN
# 4             NaN        NaN            NaN
# ...           ...        ...            ...
# 18211         NaN        NaN            NaN
# 18212         NaN        NaN            NaN
# 18213         NaN        NaN            NaN
# 18214         NaN        NaN            NaN
# 18215         NaN        NaN            NaN
#
#       Identify which division you work in. - Response  \
# 0                                      Infrastructure
# 1                                             Finance
# 2                                      Infrastructure
# 3                                      Infrastructure
# 4                                     Port Operations
# ...                                               ...
# 18211                                  Infrastructure
# 18212                                         Finance
# 18213                                 Port Operations
# 18214                                  Infrastructure
# 18215                          Information Technology
#
#                                   Question + Subquestion    Answer  \
# 0      Identify which division you work in. - Other (...       NaN
# 1      Identify which division you work in. - Other (...       NaN
# 2      Identify which division you work in. - Other (...       NaN
# 3      Identify which division you work in. - Other (...       NaN
# 4      Identify which division you work in. - Other (...       NaN
# ...                                                  ...       ...
# 18211                           Question 30 - Response 3  Answer 8
# 18212                           Question 30 - Response 3  Answer 6
# 18213                           Question 30 - Response 3       NaN
# 18214                           Question 30 - Response 3       NaN
# 18215                           Question 30 - Response 3       NaN
#
#                                    Question
# 0      Identify which division you work in.
# 1      Identify which division you work in.
# 2      Identify which division you work in.
# 3      Identify which division you work in.
# 4      Identify which division you work in.
# ...                                     ...
# 18211                           Question 30
# 18212                           Question 30
# 18213                           Question 30
# 18214                           Question 30
# 18215                           Question 30
#
# [18216 rows x 11 columns]

# %%
respondents = dataset_merged[dataset_merged["Answer"].notna()]
respondents = respondents.groupby("Question")["Respondent ID"].nunique().reset_index()
respondents.rename(columns={"Respondent ID":"Respondents"}, inplace=True)
respondents
# Out:
#                                              Question  Respondents
# 0                Identify which division you work in.            2
# 1     Please select the gender in which you identify.          196
# 2                                          Question 1          119
# 3                                         Question 10          198
# 4                                         Question 11          164
# 5                                         Question 12          114
# 6                                         Question 13          108
# 7                                         Question 14          105
# 8                                         Question 15          114
# 9                                         Question 16          117
# 10                                        Question 17          135
# 11                                        Question 18          109
# 12                                        Question 19          157
# 13                                         Question 2          118
# 14                                        Question 20          105
# 15                                        Question 21          127
# 16                                        Question 22          160
# 17                                        Question 23          120
# 18                                        Question 24          195
# 19                                        Question 25          198
# 20                                        Question 26          193
# 21                                        Question 27          153
# 22                                        Question 28          119
# 23                                        Question 29          198
# 24                                         Question 3          117
# 25                                        Question 30          182
# 26                                         Question 4          161
# 27                                         Question 5          194
# 28                                         Question 6          196
# 29                                         Question 7          162
# 30                                         Question 8          190
# 31                                         Question 9          188
# 32  Which duration range best aligns with your ten...          198
# 33                 Which generation are you apart of?          196
# 34  Which of the following best describes your emp...          198
# 35  Which of the following best describes your pos...          196

# %%
dataset_merged_two = pd.merge(left=dataset_merged, right=respondents, how="left", left_on="Question", right_on="Question")
print("Original Data", len(dataset_merged))
print("Merged Data", len(dataset_merged_two))
dataset_merged_two
# Out:
# Original Data 18216
# Merged Data 18216
#        Respondent ID          Start Date            End Date  Email Address  \
# 0         5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1         2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2         4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3         5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4         3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ...              ...                 ...                 ...            ...
# 18211     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 18212     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 18213     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 18214     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 18215     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#        First Name  Last Name  Custom Data 1  \
# 0             NaN        NaN            NaN
# 1             NaN        NaN            NaN
# 2             NaN        NaN            NaN
# 3             NaN        NaN            NaN
# 4             NaN        NaN            NaN
# ...           ...        ...            ...
# 18211         NaN        NaN            NaN
# 18212         NaN        NaN            NaN
# 18213         NaN        NaN            NaN
# 18214         NaN        NaN            NaN
# 18215         NaN        NaN            NaN
#
#       Identify which division you work in. - Response  \
# 0                                      Infrastructure
# 1                                             Finance
# 2                                      Infrastructure
# 3                                      Infrastructure
# 4                                     Port Operations
# ...                                               ...
# 18211                                  Infrastructure
# 18212                                         Finance
# 18213                                 Port Operations
# 18214                                  Infrastructure
# 18215                          Information Technology
#
#                                   Question + Subquestion    Answer  \
# 0      Identify which division you work in. - Other (...       NaN
# 1      Identify which division you work in. - Other (...       NaN
# 2      Identify which division you work in. - Other (...       NaN
# 3      Identify which division you work in. - Other (...       NaN
# 4      Identify which division you work in. - Other (...       NaN
# ...                                                  ...       ...
# 18211                           Question 30 - Response 3  Answer 8
# 18212                           Question 30 - Response 3  Answer 6
# 18213                           Question 30 - Response 3       NaN
# 18214                           Question 30 - Response 3       NaN
# 18215                           Question 30 - Response 3       NaN
#
#                                    Question  Respondents
# 0      Identify which division you work in.            2
# 1      Identify which division you work in.            2
# 2      Identify which division you work in.            2
# 3      Identify which division you work in.            2
# 4      Identify which division you work in.            2
# ...                                     ...          ...
# 18211                           Question 30          182
# 18212                           Question 30          182
# 18213                           Question 30          182
# 18214                           Question 30          182
# 18215                           Question 30          182
#
# [18216 rows x 12 columns]

# %%
same_answer = dataset_merged # [dataset_merged["Answer"].notna()]
same_answer = same_answer.groupby(["Question + Subquestion", "Answer"])["Respondent ID"].nunique().reset_index()
same_answer.rename(columns={"Respondent ID":"Same Answer"}, inplace=True)
same_answer
# Out:
#                                 Question + Subquestion              Answer  \
# 0    Identify which division you work in. - Other (...       Construction
# 1    Identify which division you work in. - Other (...      Rather not say
# 2    Please select the gender in which you identify...              Female
# 3    Please select the gender in which you identify...                Male
# 4    Please select the gender in which you identify...          Non-Binary
# ..                                                 ...                 ...
# 703  Which of the following best describes your emp...  Full time Employee
# 704  Which of the following best describes your pos...   Chief / Executive
# 705  Which of the following best describes your pos...     Department Lead
# 706  Which of the following best describes your pos...             Manager
# 707  Which of the following best describes your pos...               Staff
#
#      Same Answer
# 0              1
# 1              1
# 2             96
# 3             86
# 4              1
# ..           ...
# 703          198
# 704            6
# 705           28
# 706           46
# 707          116
#
# [708 rows x 3 columns]

# %%
dataset_merged_three = pd.merge(left=dataset_merged_two, right=same_answer, how="left", left_on=["Question + Subquestion", "Answer"], right_on=["Question + Subquestion", "Answer"])
dataset_merged_three["Same Answer"].fillna(0, inplace=True)
print("Original Data", len(dataset_merged_two))
print("Merged Data", len(dataset_merged_three))
dataset_merged_three
# Out:
# Original Data 18216
# Merged Data 18216
#        Respondent ID          Start Date            End Date  Email Address  \
# 0         5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1         2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2         4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3         5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4         3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ...              ...                 ...                 ...            ...
# 18211     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 18212     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 18213     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 18214     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 18215     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#        First Name  Last Name  Custom Data 1  \
# 0             NaN        NaN            NaN
# 1             NaN        NaN            NaN
# 2             NaN        NaN            NaN
# 3             NaN        NaN            NaN
# 4             NaN        NaN            NaN
# ...           ...        ...            ...
# 18211         NaN        NaN            NaN
# 18212         NaN        NaN            NaN
# 18213         NaN        NaN            NaN
# 18214         NaN        NaN            NaN
# 18215         NaN        NaN            NaN
#
#       Identify which division you work in. - Response  \
# 0                                      Infrastructure
# 1                                             Finance
# 2                                      Infrastructure
# 3                                      Infrastructure
# 4                                     Port Operations
# ...                                               ...
# 18211                                  Infrastructure
# 18212                                         Finance
# 18213                                 Port Operations
# 18214                                  Infrastructure
# 18215                          Information Technology
#
#                                   Question + Subquestion    Answer  \
# 0      Identify which division you work in. - Other (...       NaN
# 1      Identify which division you work in. - Other (...       NaN
# 2      Identify which division you work in. - Other (...       NaN
# 3      Identify which division you work in. - Other (...       NaN
# 4      Identify which division you work in. - Other (...       NaN
# ...                                                  ...       ...
# 18211                           Question 30 - Response 3  Answer 8
# 18212                           Question 30 - Response 3  Answer 6
# 18213                           Question 30 - Response 3       NaN
# 18214                           Question 30 - Response 3       NaN
# 18215                           Question 30 - Response 3       NaN
#
#                                    Question  Respondents  Same Answer
# 0      Identify which division you work in.            2          0.0
# 1      Identify which division you work in.            2          0.0
# 2      Identify which division you work in.            2          0.0
# 3      Identify which division you work in.            2          0.0
# 4      Identify which division you work in.            2          0.0
# ...                                     ...          ...          ...
# 18211                           Question 30          182         14.0
# 18212                           Question 30          182         20.0
# 18213                           Question 30          182          0.0
# 18214                           Question 30          182          0.0
# 18215                           Question 30          182          0.0
#
# [18216 rows x 13 columns]

# %%
output = dataset_merged_three.copy()
output.rename(columns={"Identify which division you work in. - Response":"Division Primary", "Identify which division you work in. - Other (please specify)":"Division Secondary", "Which of the following best describes your position level? - Response":"Position", "Which generation are you apart of? - Response":"Generation", "Please select the gender in which you identify. - Response":"Gender", "Which duration range best aligns with your tenure at your company? - Response":"Tenure", "Which of the following best describes your employment type? - Response":"Employment Type"}, inplace=True)
output
# Out:
#        Respondent ID          Start Date            End Date  Email Address  \
# 0         5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1         2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2         4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3         5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4         3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ...              ...                 ...                 ...            ...
# 18211     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 18212     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 18213     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 18214     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 18215     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#        First Name  Last Name  Custom Data 1        Division Primary  \
# 0             NaN        NaN            NaN          Infrastructure
# 1             NaN        NaN            NaN                 Finance
# 2             NaN        NaN            NaN          Infrastructure
# 3             NaN        NaN            NaN          Infrastructure
# 4             NaN        NaN            NaN         Port Operations
# ...           ...        ...            ...                     ...
# 18211         NaN        NaN            NaN          Infrastructure
# 18212         NaN        NaN            NaN                 Finance
# 18213         NaN        NaN            NaN         Port Operations
# 18214         NaN        NaN            NaN          Infrastructure
# 18215         NaN        NaN            NaN  Information Technology
#
#                                   Question + Subquestion    Answer  \
# 0      Identify which division you work in. - Other (...       NaN
# 1      Identify which division you work in. - Other (...       NaN
# 2      Identify which division you work in. - Other (...       NaN
# 3      Identify which division you work in. - Other (...       NaN
# 4      Identify which division you work in. - Other (...       NaN
# ...                                                  ...       ...
# 18211                           Question 30 - Response 3  Answer 8
# 18212                           Question 30 - Response 3  Answer 6
# 18213                           Question 30 - Response 3       NaN
# 18214                           Question 30 - Response 3       NaN
# 18215                           Question 30 - Response 3       NaN
#
#                                    Question  Respondents  Same Answer
# 0      Identify which division you work in.            2          0.0
# 1      Identify which division you work in.            2          0.0
# 2      Identify which division you work in.            2          0.0
# 3      Identify which division you work in.            2          0.0
# 4      Identify which division you work in.            2          0.0
# ...                                     ...          ...          ...
# 18211                           Question 30          182         14.0
# 18212                           Question 30          182         20.0
# 18213                           Question 30          182          0.0
# 18214                           Question 30          182          0.0
# 18215                           Question 30          182          0.0
#
# [18216 rows x 13 columns]

# %%
output.to_excel(pwd + "/Final_Output.xlsx", index=False)
